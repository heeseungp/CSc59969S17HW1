# %%
from IPython.display import Image
Image(filename = '1D.png')

# %% [markdown]
# # 1D Time Series
# This is a visualization using 1D time series because it uses two variables, the first being the wind speed and second being the time in years. This graph is a series of wind speed vs. time data points indexed in time order.

# %%
Image(filename = '2Dscalar.png')

# %% [markdown]
# # 2D scalar and 2D vector
# The first graph is a 2D scalar field data type and second graph below is a 2D vector graph. The first graph shows the elevation level using different colors as well as using lines to note the separation in different elevation levels. The second graph utilizes vector which show the speed and direction each arrow (vector).

# %%
Image(filename = '3D.jpg')

# %% [markdown]
# # 3D scalar field
# This data shows the Boston's Monthly Temperatures from 1900 - 2000 using 3D scalar field which use temperature as the y-axis, month as the x-axis, and year as the z-axis. Each data in month, year, temperature is represented by a bar graph, the higher the bar, the higher the temperature of that month is.

# %%
Image(filename = '3dshape.png')

# %% [markdown]
# # 3D Shape
# This is a 3D shape data type used to visualize a shape of a cylinder. It does not have any quantifiable data, but rather it is to show how physicality of an object.

# %%
Image(filename = 'graph.jpg')

# %% [markdown]
# # Graph (not tree)
# This is a compilation of 72 million electronic records of the connection of one disease with another (which shows the strength of the connection of catching one disease due to another).
